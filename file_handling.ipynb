# %%
with open("joke.txt" , "w") as f:
    f.write("Enjoy Journey of Python learning")

# %%
with open("joke.txt" , "r") as f:
    content  = f.read()
    print(content)
# Out:
# Enjoy Journey of Python learning
